# %%
latitude = 31.520370
longitude = 74.358749
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


! pip install folium==0.5.0
import folium # plotting library
from ipykernel import kernelapp



print('Folium installed')
print('Libraries imported.')
# Out:
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# ...
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# ...
#      |████████████████████████████████| 79 kB 13.7 MB/s eta 0:00:01
# ...

# %%
 from ipykernel import kernelapp as app

# %%
CLIENT_ID = 'QUEK3BKZF02PKCEOI0A1H3HGZXCK34TVNAY0ALSRTM0IVR3V' # your Foursquare ID
CLIENT_SECRET = '4Z5YCWIEMNY4ST0R3RUVW12DT0T1OCKAM4KVRUCOMBXKUNDU' # your Foursquare Secret
ACCESS_TOKEN = 'JQN40OG1YG1C0GON2AGQMOYID2ZPZZMWV0CWVCTJHYQOOVR4' # your FourSquare Access Token
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: QUEK3BKZF02PKCEOI0A1H3HGZXCK34TVNAY0ALSRTM0IVR3V
# CLIENT_SECRET:4Z5YCWIEMNY4ST0R3RUVW12DT0T1OCKAM4KVRUCOMBXKUNDU

# %%
latitude = 31.520370
longitude = 74.358749
radius = 5000

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=QUEK3BKZF02PKCEOI0A1H3HGZXCK34TVNAY0ALSRTM0IVR3V&client_secret=4Z5YCWIEMNY4ST0R3RUVW12DT0T1OCKAM4KVRUCOMBXKUNDU&ll=31.52037,74.358749&v=20180604&radius=5000&limit=30'

# %%
# Out:
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# ...
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# ...
# Folium installed
# Libraries imported.

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '6108eb49c7ad4779e5370220'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Lahore',
#   'headerFullLocation': 'Lahore',
#   'headerLocationGranularity': 'city',
#   'totalResults': 56,
#   'suggestedBounds': {'ne': {'lat': 31.565370045000044,
#     'lng': 74.41143924056381},
#    'sw': {'lat': 31.475369954999955, 'lng': 74.3060587594362}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55941af9498e4e911072ca35',
#        'name': 'Spice Bazar',
#        'location': {'address': 'T-01, Off MM Alam Road, Block T, Gulberg 2',
#         'lat': 31.518703,
#         'lng': 74.35493,
# ...

# %%
items = results['response']['groups'][0]['items']
items[0]

x
# Out:
# [{'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '55941af9498e4e911072ca35',
#    'name': 'Spice Bazar',
#    'location': {'address': 'T-01, Off MM Alam Road, Block T, Gulberg 2',
#     'lat': 31.518703,
#     'lng': 74.35493,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 31.518703,
#       'lng': 74.35493}],
#     'distance': 407,
#     'cc': 'PK',
#     'city': 'لاہور',
#     'state': 'Punjab',
#     'country': 'پاکستان',
#     'formattedAddress': ['T-01, Off MM Alam Road, Block T, Gulberg 2',
#      'لاہور',
#      'پاکستان']},
#    'categories': [{'id': '52e81612bcbc57f1066b79f8',
#      'name': 'Pakistani Restaurant',
#      'pluralName': 'Pakistani Restaurants',
#      'shortName': 'Pakistani',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'},
#      'primary': True}],
# ...

# %%
dataframe = json_normalize(x)

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]



# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]




dataframe_filtered.head(10)
# Out:
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/ipykernel/__main__.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   if __name__ == '__main__':
#                               name  \
# 0                      Spice Bazar
# 1                Tuscany Courtyard
# 2                     Dream Lounge
# 3                      Cosa Nostra
# 4                       Jalal Sons
# 5        Chaayè Khaana MM Alam Rd.
# 6                        Jade Cafe
# 7  Yum Chinese and Thai Restaurant
# 8               Paradise Ice Cream
# 9                    Variety Books
#
#                                           categories  \
# 0  [{'id': '52e81612bcbc57f1066b79f8', 'name': 'P...
# 1  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...
# 2  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...
# 3  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...
# 4  [{'id': '4bf58dd8d48988d1f6941735', 'name': 'D...
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=12) # generate map centred around Ecco


# add Ecco as a red circle mark
#folium.CircleMarker(
 #   [latitude, longitude],
  #  radius=10,
   # popup='Ecco',
    #fill=True,
    #color='red',
    #fill_color='red',
    #fill_opacity=0.6
    #).add_to(venues_map)

# add popular spots to the map as blue circle markers
for lat, lng in zip(dataframe_filtered.lat, dataframe_filtered.lng,):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup='Restaurant',
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)


# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %%
# !conda install -c conda-forgefolium=0.5.0 --yes
# !pip install folium
import folium
from IPython.display import HTML, display
import folium
# Out:
# CondaValueError: too few arguments, must supply command line package specs or --file
#
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-OpenCE/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# ...
#      |████████████████████████████████| 94 kB 9.1 MB/s  eta 0:00:01
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=12) # generate map centred around Ecco


# add Ecco as a red circle mark
#folium.CircleMarker(
 #   [latitude, longitude],
  #  radius=10,
   # popup='Ecco',
    #fill=True,
    #color='red',
    #fill_color='red',
    #fill_opacity=0.6
    #).add_to(venues_map)




# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
